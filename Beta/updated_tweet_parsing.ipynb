# %%
from tweet_parser.tweet import Tweet
from tweet_parser.tweet_parser_errors import NotATweetError, UnexpectedFormatError
import fileinput
import json
import string
import re
import time
import csv
import geopy.distance
import nltk
# nltk.download('vader_lexicon')
# nltk.download('universal_tagset')
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
from nltk.util import ngrams
from nltk.sentiment import SentimentIntensityAnalyzer
from google.cloud import storage

# Create bucket client and authenticate via service account access key
storage_client = storage.Client.from_service_account_json('/srv/Twitter2030/Data/acts-cloud-5-tljh-8e85a08eab1d-sakey.json')

BUCKET_NAME = 'allteamsmlb' # Do not change

sia = SentimentIntensityAnalyzer()

print('El Fin')
# Out:
# El Fin

# %%
team_names = [
    '02Angels', '03Athletics', '04Mariners', '05Astros', '06Rangers', '07Rockies', '08Padres', '09Dodgers', '10Giants', '11Diamondbacks',
    '12Cardinals', '13Reds', '14Cubs', '15Pirates', '16Brewers', '17Braves', '18Mets', '19Phillies', '20Marlins', '21Nationals',
    '22Indians', '23Twins', '24Royals', '25Tigers', '26WhiteSox', '27Yankees', '28Rays', '29RedSox', '30Orioles', '31BlueJays'
]

team_abbrevs = [
    'ANA', 'OAK', 'SEA', 'HOU', 'TEX', 'COL', 'SDP', 'LAD', 'SFG', 'AZ', 'STL', 'CIN', 'CHC', 'PIT', 'MIL',
    'ATL', 'NYM', 'PHI', 'FLA', 'WSN', 'CLE', 'MIN', 'KCR', 'DET', 'CHW', 'NYY', 'TBD', 'BOS', 'BAL', 'TOR'
]

# TODO: Check for negative longitudes in the tweets
team_lats = {
    'ANA': 33.800031, 'OAK': 37.751614, 'SEA': 47.591217, 'HOU': 29.757224, 'TEX': 32.751207,
    'COL': 39.755878, 'SDP': 32.707206, 'LAD': 34.07358, 'SFG': 37.778361, 'AZ': 33.445498,
    'STL': 38.62248, 'CIN': 39.097392, 'CHC': 41.948036, 'PIT': 40.446993, 'MIL': 43.02834,
    'ATL': 33.890961, 'NYM': 40.756743, 'PHI': 39.905763, 'FLA': 25.778194, 'WSN': 38.872705,
    'CLE': 41.496183, 'MIN': 44.981703, 'KCR': 39.051355, 'DET': 42.339308, 'CHW': 41.830087,
    'NYY': 40.829519, 'TBD': 27.768214, 'BOS': 42.346361, 'BAL': 39.283658, 'TOR': 43.641684
}

team_longs = {
    'ANA': -117.883017, 'OAK': -122.200574, 'SEA': -122.332721, 'HOU': -95.35521, 'TEX': -97.082635,
    'COL': -104.994192, 'SDP': -117.15706, 'LAD': -118.240147, 'SFG': -122.389712, 'AZ': -112.066694,
    'STL': -90.193205, 'CIN': -84.506852, 'CHC': -87.65569, 'PIT': -80.005987, 'MIL': -87.971451,
    'ATL': -84.467772, 'NYM': -73.845994, 'PHI': -75.166574, 'FLA': -80.219668, 'WSN': -77.007632,
    'CLE': -81.685699, 'MIN': -93.278072, 'KCR': -94.480666, 'DET': -83.048876, 'CHW': -87.63405,
    'NYY': -73.926739, 'TBD': -82.653295, 'BOS': -71.097631, 'BAL': -76.621801, 'TOR': -79.389235
}

super_list_old = [
    ['NOUN', 'VERB', 'ADV'], ['NOUN', 'VERB', 'ADP'], ['NOUN', 'VERB', 'ADV', 'ADJ'],
    ['NOUN', 'VERB', 'NOUN', 'ADP'], ['NOUN', 'VERB', 'ADJ'], ['NOUN', 'VERB', 'ADJ', 'NOUN']
]

# TODO: Get new super_list
super_list_new = []

# Happy Emoticons
emoticons_happy_old = [
    ':-)', ':)', ';)', ':o)', ':]', ':c)', ':>', '=]', '=)', ':}', ':^)', ':-D',
    ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D', ':-))', ":'-)",
    ":')", ':^*', '>:P', ':-P', ':P', ':-p', ':p', '=p', ':-b', ':b', '>:)',
    '>;)', '>:-)', '<3', '☺️', '😚', '😙', '😋', '😛', '😜', '😝', '🤗', '😏',
    '😌', '🥳', '😎', '😺', '😸', '😹', '😻', '😼', '😽', '👍', '👏', '🙌',
    '😀', '😃', '😄', '😁', '😆', '😅', '🤣', '😂', '🙂', '😉', '😊', '😇',
    '🥰', '😍', '🤩', '😘', '🎉', '🎊', '💘', '💝', '💖', '💗', '💓', '💞',
    '💕', '💟', '❣️', '❤️‍🔥', '❤️', '🧡', '💛', '💚', '💙', '💜', '🤎', '🖤',
    '🤍', '💯'
    ]

emoticons_happy_new = [
    ':-)', ':)', ';)', ':o)', ':]', ':c)', '=]', '=)', ':^)', ':D', 'xD', 'XD',
    '=-D', '=D', ':-))', ":'-)", ":')", '>:)', '>;)', '>:-)', '<3', '☺️', '😚',
    '😙', '😋', '😛', '😜', '😝', '🤗', '😏', '😌', '🥳', '😎', '😺', '😸', '😹', '😻',
    '😼', '😽', '👍', '👏', '🙌', '😀', '😃', '😄', '😁', '😆', '😅', '🤣', '😂', '🙂',
    '😉', '😊', '😇', '🥰', '😍', '🤩', '😘', '🎉', '🎊', '💘', '💝', '💖', '💗', '💓',
    '💞', '💕', '💟', '❣️', '❤️‍🔥', '❤️', '🧡', '💛', '💚', '💙', '💜', '🤎',
    '🖤', '🤍', '💯'
    ]

# Sad Emoticons
emoticons_sad_old = [
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', '>:\\', ';(', '😒', '😔', '🤢', '🤮', '🤧', '🥴', '😕', '😟', '🙁',
    '☹️', '😦', '😧', '😨', '😰', '😥', '😢', '😭', '😱', '😖', '😣', '😞',
    '😓', '😩', '😫', '😤', '😡', '😠', '🤬', '👿', '😿', '😾', '🖕', '👎',
    '🙍', '🙍‍♂️', '🙍‍♀️', '🙎', '🙎‍♂️', '🙎‍♀️', '🤦', '🤦‍♂️', '🤦‍♀️', '💔', '💢'
    ]

# Sad Emoticons
emoticons_sad_new = [
    ':-/', '>:/', '>:[', ':-(', ':[', ':-||', ':-[', ':-<', '=\\', '=/', '>:(',
    ':(', '>.<', ":'-(", ":'(", ':\\', ':-c', ':c', '>:\\', ';(', '😒', '😔', '🤢',
    '🤮', '🤧', '🥴', '😕', '😟', '🙁', '☹️', '😦', '😧', '😨', '😰', '😥', '😢',
    '😭', '😱', '😖', '😣', '😞', '😓', '😩', '😫', '😤', '😡', '😠', '🤬', '👿', '😿',
    '😾', '🖕', '👎', '🙍', '🙍‍♂️', '🙍‍♀️', '🙎', '🙎‍♂️', '🙎‍♀️', '🤦', '🤦‍♂️',
    '🤦‍♀️', '💔', '💢'
    ]

print('El Fin')
# Out:
# El Fin

# %%
def clean_tweet(tweet):
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)

    # remove old style retweet text 'RT'
    tweet = re.sub(r'^RT[\s]+', '', tweet)

    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)

    # remove hashtags
    tweet = re.sub(r'#', '', tweet)

    return tweet


intervals = (
    ('weeks', 604800),  # 60 * 60 * 24 * 7
    ('days', 86400),  # 60 * 60 * 24
    ('hours', 3600),  # 60 * 60
    ('minutes', 60),
    ('seconds', 1),
)


def display_time(seconds, granularity=2):
    result = []

    for name, count in intervals:
        value = seconds // count
        if value:
            seconds -= value * count
            if value == 1:
                name = name.rstrip('s')
            result.append("{} {}".format(round(value), name))
    return ', '.join(result[:granularity])


def increment_dict(key, dictionary):
    if key in dictionary.keys():
        dictionary[key] += 1
    else:
        dictionary[key] = 1


def write_dict_to_file(file_name, dictionary):
    with open(file_name, 'w') as new_file:
        for key, value in dictionary.items():
            new_file.write('%s : %d\n' % (key, value))

print('El Fin')
# Out:
# El Fin

# %%
# Start runtime
# t0 = time.time()


# ALL TEAMS DICTS
ALL_TEAMS_bow = {}
ALL_TEAMS_total_tweets = {}


for team_name in team_names:

    team_abbrev = team_abbrevs[team_names.index(team_name)]

    dates = []

    for i in range(16, 20):
        # Atlanta 2016 is in a different stadium. Skip.
        if team_abbrev == 'ATL' and i == 16:
            continue
        with open(('Data/Team_WL/' + str(team_abbrev) + str(i) + '.csv'), newline='', encoding='utf-8-sig') as csvfile:
            reader = csv.reader(csvfile, delimiter=',', quotechar='|')
            for row in reader:
                date = row[0]
                if date.startswith('d'):
                    continue
                if not date.startswith('1'):
                    date = '0' + date
                if not date[5] == '/':
                    date = date[:3] + '0' + date[3:]
                date = date[6:] + '-' + date[:2] + '-' + date[3:-5]
                dates.append(date)


    # Average distances between tweets and stadium
    COM_average_distance = 0
    IP_average_distance = 0
    NP_average_distance = 0

    # COMBINED DICTS

    COM_bow = {}
    COM_total_tweets = {}
    COM_tweets_per_hour = {}

    # DICTS FOR TEAM IS PLAYING

    IP_bow = {}

    # Dictionaries: Key - Date/Time    Value - Number of tweets
    IP_total_tweets = {}
    IP_tweets_per_hour = {}

    IP_neg_polarity = {}
    IP_neu_polarity = {}
    IP_pos_polarity = {}
    IP_com_polarity = {}

    IP_yes_cognition_old = {}
    IP_no_cognition_old = {}

    IP_yes_cognition_new = {}
    IP_no_cognition_new = {}

    IP_happy_sentiment_old = {}
    IP_sad_sentiment_old = {}
    IP_general_sentiment_old = {}

    IP_happy_sentiment_new = {}
    IP_sad_sentiment_new = {}
    IP_general_sentiment_new = {}


    # DICTS FOR TEAM IS NOT PLAYING

    NP_bow = {}

    # Dictionaries: Key - Date/Time    Value - Number of tweets
    NP_total_tweets = {}
    NP_tweets_per_hour = {}

    NP_neg_polarity = {}
    NP_neu_polarity = {}
    NP_pos_polarity = {}
    NP_com_polarity = {}

    NP_yes_cognition_old = {}
    NP_no_cognition_old = {}

    NP_yes_cognition_new = {}
    NP_no_cognition_new = {}

    NP_happy_sentiment_old = {}
    NP_sad_sentiment_old = {}
    NP_general_sentiment_old = {}

    NP_happy_sentiment_new = {}
    NP_sad_sentiment_new = {}
    NP_general_sentiment_new = {}

    object_generator = storage_client.list_blobs(BUCKET_NAME, prefix=team_name, delimiter=None)

    for status_log_bucket_name in object_generator:

        
        # # TODO: Delete me
        # previous_parse_time = time.time()
        # bucket_time = time.time()
        # if bucket_time - t0 > 1:
        #     break

            
        client = storage.Client()
        BUCKET_NAME_TWO = client.bucket(BUCKET_NAME)
        blob = BUCKET_NAME_TWO.blob(status_log_bucket_name.name)

        with blob.open('rt') as f:
            for line in f:
                try:
                    raw_tweet = json.loads(line)

                    
#                     # TODO: Delete me
#                     start_parse_time = time.time()
#                     print('\nTWEET ACCESS TIME  - ', start_parse_time - previous_parse_time, '\n')
#                     previous_parse_time = time.time()

                    
                    tweet = Tweet(raw_tweet)

                    text = clean_tweet(tweet.all_text)
                    
                    # Extracts time, date, language, and coordinates
                    date = tweet.created_at_string[0:10]
                    hour = int(tweet.created_at_string[11:13])
                    lang = tweet.lang
                    coordinates = tweet.geo_coordinates
                    
                    # Increment combined total number of tweets
                    increment_dict(date, COM_total_tweets)
                    increment_dict(date, ALL_TEAMS_total_tweets)
                    increment_dict(hour, COM_tweets_per_hour)

                    # Increment combined total BoW
                    words = text.split()
                    for word in words:
                        new_word = word.translate(str.maketrans('', '', string.punctuation))
                        increment_dict(new_word, COM_bow)
                        increment_dict(new_word, ALL_TEAMS_bow)
                    
                    # Only operates on tweets with valid coordinates
                    if coordinates is not None and coordinates['latitude'] is not None and coordinates['longitude'] is not None:
                        tweet_lat = coordinates.get('latitude')
                        tweet_long = coordinates.get('longitude')

                        tweet_coords = (tweet_lat, tweet_long)

                        team_lat = team_lats[team_abbrev]
                        team_long = team_longs[team_abbrev]

                        team_coords = (team_lat, team_long)

                        # Distance between the tweet and stadium (meters)
                        distance = geopy.distance.geodesic(tweet_coords, team_coords).km * 1000

                        # Updates average distance
                        if COM_average_distance != 0:
                            COM_average_distance = COM_average_distance * (COM_total_tweets[date] - 1) / COM_total_tweets[date] + distance / COM_total_tweets[date]
                        else:
                            COM_average_distance = distance
                            


                    # !! TWEET PARSING !!

                    # If the team is playing


                    if date in dates and hour >= 10 and lang == 'en':

                        # Increment total number of tweets
                        increment_dict(date, IP_total_tweets)
                        increment_dict(hour, IP_tweets_per_hour)

                        # Increment total BoW
                        for word in words:
                            new_word = word.translate(str.maketrans('', '', string.punctuation))
                            increment_dict(new_word, IP_bow)

                        # Updates average distance
                        if coordinates is not None and coordinates['latitude'] is not None and coordinates['longitude'] is not None:
                            if IP_average_distance != 0:
                                IP_average_distance = IP_average_distance * (IP_total_tweets[date] - 1) / IP_total_tweets[date] + distance / IP_total_tweets[date]
                            else:
                                IP_average_distance = distance


                        # !! POLARITY !!

                        scores = sia.polarity_scores(text)  # Create a dict of scores

                        # Loop the dict of scores and increment the dicts if necessary
                        for key in scores:
                            if key == 'neg':
                                if scores[key] == 0.0:
                                    increment_dict(date, IP_neg_polarity)
                            if key == 'neu':
                                if scores[key] == 0.0:
                                    increment_dict(date, IP_neu_polarity)
                            if key == 'pos':
                                if scores[key] == 0.0:
                                    increment_dict(date, IP_pos_polarity)
                            if key == 'compound':
                                if scores[key] == 0.0:
                                    increment_dict(date, IP_com_polarity)


                        # !! COGNITION !!

                        tokens = nltk.word_tokenize(text)  # Create a list of tokens
                        tokens_tagged = nltk.pos_tag(tokens, tagset='universal')

                        pos_tokens = ''

                        # Loop the dict of tokens
                        for token in tokens_tagged:
                            pos_tokens += token[1] + ' '

                        sentence = str(pos_tokens)  # 'Whoever is happy will make others happy too'
                        trigrams = ngrams(sentence.split(), 3)
                        quadgrams = ngrams(sentence.split(), 4)

                        trigram_list = []
                        for item in trigrams:
                            trigram_list.append(item[0])
                            trigram_list.append(item[1])
                            trigram_list.append(item[2])

                        quadgram_list = []
                        for item in quadgrams:
                            quadgram_list.append(item[0])
                            quadgram_list.append(item[1])
                            quadgram_list.append(item[2])
                            quadgram_list.append(item[3])

                        # If in old list, add to dict
                        if trigram_list in super_list_old or quadgram_list in super_list_old:
                            increment_dict(date, IP_yes_cognition_old)
                        else:
                            increment_dict(date, IP_no_cognition_old)

                        # If in new list, add to dict
                        if trigram_list in super_list_new or quadgram_list in super_list_new:
                            increment_dict(date, IP_yes_cognition_new)
                        else:
                            increment_dict(date, IP_no_cognition_new)


                        # !! SENTIMENT !!

                        # If in old happy emoticons, add to dict
                        for emoticon in emoticons_happy_old:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, IP_happy_sentiment_old)
                                increment_dict(date, IP_general_sentiment_old)
                                break;

                        # If in old sad emoticons, add to dict
                        for emoticon in emoticons_sad_old:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, IP_sad_sentiment_old)
                                increment_dict(date, IP_general_sentiment_old)
                                break;

                        # If in new happy emoticons, add to dict
                        for emoticon in emoticons_happy_new:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, IP_happy_sentiment_new)
                                increment_dict(date, IP_general_sentiment_new)
                                break;

                        # If in new sad emoticons, add to dict
                        for emoticon in emoticons_sad_new:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, IP_sad_sentiment_new)
                                increment_dict(date, IP_general_sentiment_new)
                                break;


                    # If the team is NOT playing
                    else:

                        # Increment total number of tweets
                        increment_dict(date, NP_total_tweets)
                        increment_dict(hour, NP_tweets_per_hour)

                        # Increment total BoW
                        for word in words:
                            new_word = word.translate(str.maketrans('', '', string.punctuation))
                            increment_dict(new_word, NP_bow)

                        # Updates average distance
                        if coordinates is not None and coordinates['latitude'] is not None and coordinates['longitude'] is not None:
                            if NP_average_distance != 0:
                                NP_average_distance = NP_average_distance * (NP_total_tweets[date] - 1) / NP_total_tweets[date] + distance / NP_total_tweets[date]
                            else:
                                NP_average_distance = distance


                        # !! POLARITY !!

                        scores = sia.polarity_scores(text)  # Create a dict of scores

                        # Loop the dict of scores and increment the dicts if necessary
                        for key in scores:
                            if key == 'neg':
                                if scores[key] == 0.0:
                                    increment_dict(date, NP_neg_polarity)
                            if key == 'neu':
                                if scores[key] == 0.0:
                                    increment_dict(date, NP_neu_polarity)
                            if key == 'pos':
                                if scores[key] == 0.0:
                                    increment_dict(date, NP_pos_polarity)
                            if key == 'compound':
                                if scores[key] == 0.0:
                                    increment_dict(date, NP_com_polarity)


                        # !! COGNITION !!

                        tokens = nltk.word_tokenize(text)  # Create a list of tokens
                        tokens_tagged = nltk.pos_tag(tokens, tagset='universal')

                        pos_tokens = ''

                        # Loop the dict of tokens
                        for token in tokens_tagged:
                            pos_tokens += token[1] + ' '

                        sentence = str(pos_tokens)  # 'Whoever is happy will make others happy too'
                        trigrams = ngrams(sentence.split(), 3)
                        quadgrams = ngrams(sentence.split(), 4)

                        trigram_list = []
                        for item in trigrams:
                            trigram_list.append(item[0])
                            trigram_list.append(item[1])
                            trigram_list.append(item[2])

                        quadgram_list = []
                        for item in quadgrams:
                            quadgram_list.append(item[0])
                            quadgram_list.append(item[1])
                            quadgram_list.append(item[2])
                            quadgram_list.append(item[3])

                        # If in old list, add to dict
                        if trigram_list in super_list_old or quadgram_list in super_list_old:
                            increment_dict(date, NP_yes_cognition_old)
                        else:
                            increment_dict(date, NP_no_cognition_old)

                        # If in new list, add to dict
                        if trigram_list in super_list_new or quadgram_list in super_list_new:
                            increment_dict(date, NP_yes_cognition_new)
                        else:
                            increment_dict(date, NP_no_cognition_new)


                        # !! SENTIMENT !!

                        # If in old happy emoticons, add to dict
                        for emoticon in emoticons_happy_old:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, NP_happy_sentiment_old)
                                increment_dict(date, NP_general_sentiment_old)
                                break;

                        # If in old sad emoticons, add to dict
                        for emoticon in emoticons_sad_old:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, NP_sad_sentiment_old)
                                increment_dict(date, NP_general_sentiment_old)
                                break;

                        # If in new happy emoticons, add to dict
                        for emoticon in emoticons_happy_new:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, NP_happy_sentiment_new)
                                increment_dict(date, NP_general_sentiment_new)
                                break;

                        # If in new sad emoticons, add to dict
                        for emoticon in emoticons_sad_new:
                            if text.lower().find(emoticon) != -1:
                                increment_dict(date, NP_sad_sentiment_new)
                                increment_dict(date, NP_general_sentiment_new)
                                break;

                                
                    # # TODO: Delete me
                    # end_parse_time = time.time()
                    # print('\nTWEET PARSING TIME  - ', end_parse_time - start_parse_time, '\n')    
                    
                    print('\nText:', text)
                    print('Words:', words)
                    print('Date:', date)
                    print('Hour:', hour)
                    if coordinates is not None and coordinates['latitude'] is not None and coordinates['longitude'] is not None:
                        print('Coordinates:', coordinates)
                        print('Distance:', distance)
                    print('\n\n')
                            
                    

                except Exception as e:
                    # print(str(e))
                    pass


    # Write to combined average distance + total BoW/tweet text files
    with open(team_abbrev + '_COM_average_distance.txt', 'w') as new_file:
        new_file.write(str(COM_average_distance))
    write_dict_to_file(team_abbrev + '_COM_bow.txt', COM_bow)
    write_dict_to_file(team_abbrev + '_COM_total_tweets.txt', COM_total_tweets)
    write_dict_to_file(team_abbrev + '_COM_tweets_per_hour.txt', COM_tweets_per_hour)


    # TEAM IS PLAYING

    # Write to average distance + total BoW/tweet text files
    with open(team_abbrev + '_IP_average_distance.txt', 'w') as new_file:
        new_file.write(str(IP_average_distance))
    write_dict_to_file(team_abbrev + '_IP_bow.txt', IP_bow)
    write_dict_to_file(team_abbrev + '_IP_total_tweets.txt', IP_total_tweets)
    write_dict_to_file(team_abbrev + '_IP_tweets_per_hour.txt', IP_tweets_per_hour)

    # Write to polarity text files
    write_dict_to_file(team_abbrev + '_IP_pol_negative.txt', IP_neg_polarity)
    write_dict_to_file(team_abbrev + '_IP_pol_neutral.txt', IP_neu_polarity)
    write_dict_to_file(team_abbrev + '_IP_pol_positive.txt', IP_pos_polarity)
    write_dict_to_file(team_abbrev + '_IP_pol_compound.txt', IP_com_polarity)

    # Write to cognition text files old
    write_dict_to_file(team_abbrev + '_IP_cogn_yes_old.txt', IP_yes_cognition_old)
    write_dict_to_file(team_abbrev + '_IP_cogn_no_old.txt', IP_no_cognition_old)

    # Write to cognition text files new
    write_dict_to_file(team_abbrev + '_IP_cogn_yes_new.txt', IP_yes_cognition_new)
    write_dict_to_file(team_abbrev + '_IP_cogn_no_new.txt', IP_no_cognition_new)

    # Write to sentiment text files old
    write_dict_to_file(team_abbrev + '_IP_sent_happy_old.txt', IP_happy_sentiment_old)
    write_dict_to_file(team_abbrev + '_IP_sent_sad_old.txt', IP_sad_sentiment_old)
    write_dict_to_file(team_abbrev + '_IP_sent_general_old.txt', IP_general_sentiment_old)

    # Write to sentiment text files new
    write_dict_to_file(team_abbrev + '_IP_sent_happy_new.txt', IP_happy_sentiment_new)
    write_dict_to_file(team_abbrev + '_IP_sent_sad_new.txt', IP_sad_sentiment_new)
    write_dict_to_file(team_abbrev + '_IP_sent_general_new.txt', IP_general_sentiment_new)


    # TEAM NOT PLAYING:

    # Write to average distance text file
    with open(team_abbrev + '_NP_average_distance.txt', 'w') as new_file:
        new_file.write(str(NP_average_distance))

    # Write to total BoW/tweet text files
    write_dict_to_file(team_abbrev + '_NP_bow.txt', NP_bow)
    write_dict_to_file(team_abbrev + '_NP_total_tweets.txt', NP_total_tweets)
    write_dict_to_file(team_abbrev + '_NP_tweets_per_hour.txt', NP_tweets_per_hour)

    # Write to polarity text files
    write_dict_to_file(team_abbrev + '_NP_pol_negative.txt', NP_neg_polarity)
    write_dict_to_file(team_abbrev + '_NP_pol_neutral.txt', NP_neu_polarity)
    write_dict_to_file(team_abbrev + '_NP_pol_positive.txt', NP_pos_polarity)
    write_dict_to_file(team_abbrev + '_NP_pol_compound.txt', NP_com_polarity)

    # Write to cognition text files old
    write_dict_to_file(team_abbrev + '_NP_cogn_yes_old.txt', NP_yes_cognition_old)
    write_dict_to_file(team_abbrev + '_NP_cogn_no_old.txt', NP_no_cognition_old)

    # Write to cognition text files new
    write_dict_to_file(team_abbrev + '_NP_cogn_yes_new.txt', NP_yes_cognition_new)
    write_dict_to_file(team_abbrev + '_NP_cogn_no_new.txt', NP_no_cognition_new)

    # Write to sentiment text files old
    write_dict_to_file(team_abbrev + '_NP_sent_happy_old.txt', NP_happy_sentiment_old)
    write_dict_to_file(team_abbrev + '_NP_sent_sad_old.txt', NP_sad_sentiment_old)
    write_dict_to_file(team_abbrev + '_NP_sent_general_old.txt', NP_general_sentiment_old)

    # Write to sentiment text files new
    write_dict_to_file(team_abbrev + '_NP_sent_happy_new.txt', NP_happy_sentiment_new)
    write_dict_to_file(team_abbrev + '_NP_sent_sad_new.txt', NP_sad_sentiment_new)
    write_dict_to_file(team_abbrev + '_NP_sent_general_new.txt', NP_general_sentiment_new)

    # t1 = time.time()

    # print(team_name, 'DONE: Runtime  - ', display_time(t1 - t0))
    
    # TODO: Delete me
    break


# ALL TEAMS

# Write to total BoW/tweet text files
write_dict_to_file('ALL_TEAMS_bow.txt', ALL_TEAMS_bow)
write_dict_to_file('ALL_TEAMS_total_tweets.txt', ALL_TEAMS_total_tweets)


# t_final = time.time()

# print('\nTOTAL RUNTIME  - ', display_time(t_final - t0), '\n')
print('El Fin')
# Out:
# Text: DSS 26 receiving data from Mars Reconnaissance Orbiter at 3.0Mb/s.
# IN LOCK OFF 1 MCD2
# Words: ['DSS', '26', 'receiving', 'data', 'from', 'Mars', 'Reconnaissance', 'Orbiter', 'at', '3.0Mb/s.', 'IN', 'LOCK', 'OFF', '1', 'MCD2']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 35.426667, 'longitude': -116.89}
# Distance: 202125.95227738668
#
#
#
#
# Text: I will 💘 @kaylanegs you have fun on your vacation. And be safe.
# Words: ['I', 'will', '💘', '@kaylanegs', 'you', 'have', 'fun', 'on', 'your', 'vacation.', 'And', 'be', 'safe.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: "GatesCity" is  ass lmao i kept composure thru the whole thing dude is just assssss
# Words: ['"GatesCity"', 'is', 'ass', 'lmao', 'i', 'kept', 'composure', 'thru', 'the', 'whole', 'thing', 'dude', 'is', 'just', 'assssss']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: mind of mine on a late night drive
# Words: ['mind', 'of', 'mine', 'on', 'a', 'late', 'night', 'drive']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: "...what have I done..."
# Words: ['"...what', 'have', 'I', 'done..."']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: My uber driver is the cutest.
# Words: ['My', 'uber', 'driver', 'is', 'the', 'cutest.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Ok if u say so..
# Words: ['Ok', 'if', 'u', 'say', 'so..']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.69913601, 'longitude': -123.01203712}
# Distance: 634123.7167709541
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.69929, 'longitude': -123.01204174}
# Distance: 634135.342176876
#
#
#
#
# Text: @Jordan_keigher @wearebadflower
# Words: ['@Jordan_keigher', '@wearebadflower']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: gud naht fam
# Words: ['gud', 'naht', 'fam']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @AfroVII @SunGossip
# Words: ['@AfroVII', '@SunGossip']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: 5mile run @ Long Beach City College
# Words: ['5mile', 'run', '@', 'Long', 'Beach', 'City', 'College']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.8298264, 'longitude': -118.1349258}
# Distance: 23555.871909411697
#
#
#
#
# Text: Poe up @luisglo300
# Words: ['Poe', 'up', '@luisglo300']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: What a weird shift to end the week...
# Words: ['What', 'a', 'weird', 'shift', 'to', 'end', 'the', 'week...']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: i should go to bed, that's what
# Words: ['i', 'should', 'go', 'to', 'bed,', "that's", 'what']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I cannot f*** with you anymore...
# Words: ['I', 'cannot', 'f***', 'with', 'you', 'anymore...']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: It's about tomorrow
# Words: ["It's", 'about', 'tomorrow']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @naomithedolphin wack
# Words: ['@naomithedolphin', 'wack']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: iPhone 68. iPhone or Samsung?
# Words: ['iPhone', '68.', 'iPhone', 'or', 'Samsung?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Lmao this is me w @_Shitraa_ 😂 Berlin better not ever try to doubt my loyalty to her, I let her use my fav blanket. (the one I use EVERY night)
# Words: ['Lmao', 'this', 'is', 'me', 'w', '@_Shitraa_', '😂', 'Berlin', 'better', 'not', 'ever', 'try', 'to', 'doubt', 'my', 'loyalty', 'to', 'her,', 'I', 'let', 'her', 'use', 'my', 'fav', 'blanket.', '(the', 'one', 'I', 'use', 'EVERY', 'night)']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Set everything up today for a pretty cool fashion event at the cypress…
# Words: ['Set', 'everything', 'up', 'today', 'for', 'a', 'pretty', 'cool', 'fashion', 'event', 'at', 'the', 'cypress…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.8242264, 'longitude': -118.0336304}
# Distance: 14200.839159730076
#
#
#
#
# Text: Under made you'll. Gathering, i rule thing the the upon void evening greater every you're.
# Words: ['Under', 'made', "you'll.", 'Gathering,', 'i', 'rule', 'thing', 'the', 'the', 'upon', 'void', 'evening', 'greater', 'every', "you're."]
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.69919869, 'longitude': -123.01164806}
# Distance: 634102.6184452502
#
#
#
#
# Text: This song reminds me of my cousin @carinuhh__  I always cry at how hard she hit the Milly Rock in Egypt lmao
# Words: ['This', 'song', 'reminds', 'me', 'of', 'my', 'cousin', '@carinuhh__', 'I', 'always', 'cry', 'at', 'how', 'hard', 'she', 'hit', 'the', 'Milly', 'Rock', 'in', 'Egypt', 'lmao']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I just spent 16 hours in Disneyland...
# Words: ['I', 'just', 'spent', '16', 'hours', 'in', 'Disneyland...']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Annoyed 🙃
# Words: ['Annoyed', '🙃']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I have to delete all my social media by 6:00 tomorrow night
# Words: ['I', 'have', 'to', 'delete', 'all', 'my', 'social', 'media', 'by', '6:00', 'tomorrow', 'night']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Tfw two of your guys friends almost get hectic with people you know 😂
# Words: ['Tfw', 'two', 'of', 'your', 'guys', 'friends', 'almost', 'get', 'hectic', 'with', 'people', 'you', 'know', '😂']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @jenniferdurannn @princess_veli when is it?
# Words: ['@jenniferdurannn', '@princess_veli', 'when', 'is', 'it?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Can it be 1 already 😩
# Words: ['Can', 'it', 'be', '1', 'already', '😩']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: What u think @meach_16 ? Put it in some rice and it'll be cool ? softball, there's nothing soft about it 🙌🏾
# Words: ['What', 'u', 'think', '@meach_16', '?', 'Put', 'it', 'in', 'some', 'rice', 'and', "it'll", 'be', 'cool', '?', 'softball,', "there's", 'nothing', 'soft', 'about', 'it', '🙌🏾']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: As much as you want to unleash - and sometimes you can't help it. Sometimes it slips your control sometimes it's an overwhelming over
# Words: ['As', 'much', 'as', 'you', 'want', 'to', 'unleash', '-', 'and', 'sometimes', 'you', "can't", 'help', 'it.', 'Sometimes', 'it', 'slips', 'your', 'control', 'sometimes', "it's", 'an', 'overwhelming', 'over']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I always fee like running at this time
# Words: ['I', 'always', 'fee', 'like', 'running', 'at', 'this', 'time']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @srirachachella luv u 😙
# Words: ['@srirachachella', 'luv', 'u', '😙']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I just barely saw the caption now😂
# Words: ['I', 'just', 'barely', 'saw', 'the', 'caption', 'now😂']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Sleep on the last night of break or not 🤔
# Words: ['Sleep', 'on', 'the', 'last', 'night', 'of', 'break', 'or', 'not', '🤔']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Three niggas to turnt lmao
# Words: ['Three', 'niggas', 'to', 'turnt', 'lmao']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: update: Men's won silver but they must not be too happy bout it cuz im not hearing too much from them lol
# Words: ['update:', "Men's", 'won', 'silver', 'but', 'they', 'must', 'not', 'be', 'too', 'happy', 'bout', 'it', 'cuz', 'im', 'not', 'hearing', 'too', 'much', 'from', 'them', 'lol']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @arevk7 okay But after you teach me those wonderful dance moves
# Words: ['@arevk7', 'okay', 'But', 'after', 'you', 'teach', 'me', 'those', 'wonderful', 'dance', 'moves']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Lol I literally have no care for her but I don't understand where the h8 stems from yeah halsey has done some unnecessary things but do you realize how dumb and hypocritical you all are for insulting her 24/7
# Words: ['Lol', 'I', 'literally', 'have', 'no', 'care', 'for', 'her', 'but', 'I', "don't", 'understand', 'where', 'the', 'h8', 'stems', 'from', 'yeah', 'halsey', 'has', 'done', 'some', 'unnecessary', 'things', 'but', 'do', 'you', 'realize', 'how', 'dumb', 'and', 'hypocritical', 'you', 'all', 'are', 'for', 'insulting', 'her', '24/7']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: first ride. 50 degrees. soaked. what FUN! californiaadventure…
# Words: ['first', 'ride.', '50', 'degrees.', 'soaked.', 'what', 'FUN!', 'californiaadventure…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.8171376, 'longitude': -117.9224121}
# Distance: 4111.649122675682
#
#
#
#
# Text: Yes&amp;yeeess🍑 I mean why not🤔
# Words: ['Yes&amp;yeeess🍑', 'I', 'mean', 'why', 'not🤔']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: bubbling urge that rages forth and as much as you intend not to it comes out..
# Words: ['bubbling', 'urge', 'that', 'rages', 'forth', 'and', 'as', 'much', 'as', 'you', 'intend', 'not', 'to', 'it', 'comes', 'out..']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Happy birthday pretty girl! hope you have a great day! we gotta celebrate soon, love you sweet thang 💗😻 @_diaanam
# Words: ['Happy', 'birthday', 'pretty', 'girl!', 'hope', 'you', 'have', 'a', 'great', 'day!', 'we', 'gotta', 'celebrate', 'soon,', 'love', 'you', 'sweet', 'thang', '💗😻', '@_diaanam']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm sleepy gn I love you all. Goodnight Faith, Kira, Marina, Steph, Kristina, Mace, my sow and ptb fam.💛 and Owen too, I guess.🙄
# Words: ["I'm", 'sleepy', 'gn', 'I', 'love', 'you', 'all.', 'Goodnight', 'Faith,', 'Kira,', 'Marina,', 'Steph,', 'Kristina,', 'Mace,', 'my', 'sow', 'and', 'ptb', 'fam.💛', 'and', 'Owen', 'too,', 'I', 'guess.🙄']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: lmao over ittttt
# Words: ['lmao', 'over', 'ittttt']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: same af  why is oomf ALWAYS at circle k when I am lmao
# Words: ['same', 'af', 'why', 'is', 'oomf', 'ALWAYS', 'at', 'circle', 'k', 'when', 'I', 'am', 'lmao']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'll bump this fucking song anywhere at anytime idgaf this song is the best THIS SONG MADE ME WANT A ONE NIGHT STAND!
# Words: ["I'll", 'bump', 'this', 'fucking', 'song', 'anywhere', 'at', 'anytime', 'idgaf', 'this', 'song', 'is', 'the', 'best', 'THIS', 'SONG', 'MADE', 'ME', 'WANT', 'A', 'ONE', 'NIGHT', 'STAND!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Georfucked with my nigguhs
# Words: ['Georfucked', 'with', 'my', 'nigguhs']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I always feel like running at this time
# Words: ['I', 'always', 'feel', 'like', 'running', 'at', 'this', 'time']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: but if you get that moment...if you have that chance to stop yourself...then stop.
# Words: ['but', 'if', 'you', 'get', 'that', 'moment...if', 'you', 'have', 'that', 'chance', 'to', 'stop', 'yourself...then', 'stop.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @munkuhhhh LMFAO I'm dying 😂😫😂😫😂😫😂😫😂😫😂😫😂😫😂😫😂😫
# Words: ['@munkuhhhh', 'LMFAO', "I'm", 'dying', '😂😫😂😫😂😫😂😫😂😫😂😫😂😫😂😫😂😫']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Kevin Gates is fucking awesome.  @KenlyTheBeast
# Words: ['Kevin', 'Gates', 'is', 'fucking', 'awesome.', '@KenlyTheBeast']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: S/O to the crazy homeless man for harassing all of our customers and employees, stealing food, and being a creep. You are a star💫
# Words: ['S/O', 'to', 'the', 'crazy', 'homeless', 'man', 'for', 'harassing', 'all', 'of', 'our', 'customers', 'and', 'employees,', 'stealing', 'food,', 'and', 'being', 'a', 'creep.', 'You', 'are', 'a', 'star💫']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: simply an amazing night... The Killers
# Words: ['simply', 'an', 'amazing', 'night...', 'The', 'Killers']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: School is s struggle 🗣
# Words: ['School', 'is', 's', 'struggle', '🗣']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: needing you once again
# Words: ['needing', 'you', 'once', 'again']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @serenademariah omw sugar
# Words: ['@serenademariah', 'omw', 'sugar']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I see u on Twitter but no text back, i see ur priorities, don't get mad when I lag for 3 days💁🏻
# Words: ['I', 'see', 'u', 'on', 'Twitter', 'but', 'no', 'text', 'back,', 'i', 'see', 'ur', 'priorities,', "don't", 'get', 'mad', 'when', 'I', 'lag', 'for', '3', 'days💁🏻']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: damn ma
# Words: ['damn', 'ma']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @JonBrownell_ 😈👏🏻👏🏻👏🏻👏🏻
# Words: ['@JonBrownell_', '😈👏🏻👏🏻👏🏻👏🏻']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @_ogcaaarms  😂🤔😍 when you get that confirmation that he coming over
# Words: ['@_ogcaaarms', '😂🤔😍', 'when', 'you', 'get', 'that', 'confirmation', 'that', 'he', 'coming', 'over']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: What would the you from tomorrow say?
# Words: ['What', 'would', 'the', 'you', 'from', 'tomorrow', 'say?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: チャプチェー！diamondjamboree Irvine bcdtofu
# Words: ['チャプチェー！diamondjamboree', 'Irvine', 'bcdtofu']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @Helen_Ochoa triunfando El Malecon Nightclub de Lakewood, CA!!!H8A HelenOchoa…
# Words: ['@Helen_Ochoa', 'triunfando', 'El', 'Malecon', 'Nightclub', 'de', 'Lakewood,', 'CA!!!H8A', 'HelenOchoa…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.85208, 'longitude': -118.13453}
# Distance: 23988.3026274252
#
#
#
#
# Text: @Ohhmyyjailenee sucks to suck 😂😂😂😴
# Words: ['@Ohhmyyjailenee', 'sucks', 'to', 'suck', '😂😂😂😴']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Who else trynna get on my head tonight ?
# Words: ['Who', 'else', 'trynna', 'get', 'on', 'my', 'head', 'tonight', '?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Tryina smash ass
# Words: ['Tryina', 'smash', 'ass']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @lannie_rhea @harelesspotter
# Words: ['@lannie_rhea', '@harelesspotter']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @arianarachel07 want me to go over?? You can play with my hair while I lay down and sleep and you can feed me  😊😊😊
# Words: ['@arianarachel07', 'want', 'me', 'to', 'go', 'over??', 'You', 'can', 'play', 'with', 'my', 'hair', 'while', 'I', 'lay', 'down', 'and', 'sleep', 'and', 'you', 'can', 'feed', 'me', '😊😊😊']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: hapy birdday u accident
# Words: ['hapy', 'birdday', 'u', 'accident']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @AlyciaTyre @__kassaandraa__
# Words: ['@AlyciaTyre', '@__kassaandraa__']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Would you wake up with regrets? If you're the type of person to feel them?
# Words: ['Would', 'you', 'wake', 'up', 'with', 'regrets?', 'If', "you're", 'the', 'type', 'of', 'person', 'to', 'feel', 'them?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I swear I don't go out , and it's not because I can't go out lol I choose not too because y'all bitches just on another level ... 😰
# Words: ['I', 'swear', 'I', "don't", 'go', 'out', ',', 'and', "it's", 'not', 'because', 'I', "can't", 'go', 'out', 'lol', 'I', 'choose', 'not', 'too', 'because', "y'all", 'bitches', 'just', 'on', 'another', 'level', '...', '😰']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @heyzol_ tf is this my nigga ? 😂
# Words: ['@heyzol_', 'tf', 'is', 'this', 'my', 'nigga', '?', '😂']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: in that love phase everyday
# Words: ['in', 'that', 'love', 'phase', 'everyday']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: School is a stuggle
# Words: ['School', 'is', 'a', 'stuggle']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @aliciahunt95 omg
# Words: ['@aliciahunt95', 'omg']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Mayhap you're not..
# Words: ['Mayhap', "you're", 'not..']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: HealthWelfare Job in CostaMesa, CA: Health Enthusiast Part-Time at The Vitamin Shoppe
# Words: ['HealthWelfare', 'Job', 'in', 'CostaMesa,', 'CA:', 'Health', 'Enthusiast', 'Part-Time', 'at', 'The', 'Vitamin', 'Shoppe']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.6295576, 'longitude': -117.9096835}
# Distance: 19069.31556120022
#
#
#
#
# Text: Never a dull moment w them 💕
# Words: ['Never', 'a', 'dull', 'moment', 'w', 'them', '💕']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @iNawafx7 Good luck
# Words: ['@iNawafx7', 'Good', 'luck']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @Hypercte @RoraCollective @Bracketsongs @gupimusic @TheSonderMusic you're so sweet, my boy. thank you for the support! 💕
# Words: ['@Hypercte', '@RoraCollective', '@Bracketsongs', '@gupimusic', '@TheSonderMusic', "you're", 'so', 'sweet,', 'my', 'boy.', 'thank', 'you', 'for', 'the', 'support!', '💕']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I have to get up at like 5:30 for a debate tournament that I'm still preparing for HAHA
# Words: ['I', 'have', 'to', 'get', 'up', 'at', 'like', '5:30', 'for', 'a', 'debate', 'tournament', 'that', "I'm", 'still', 'preparing', 'for', 'HAHA']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: but mostly around this time
# Words: ['but', 'mostly', 'around', 'this', 'time']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @macktology101 *exhales deeply*
# Words: ['@macktology101', '*exhales', 'deeply*']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Finally went Out
# Words: ['Finally', 'went', 'Out']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @mark_hernandez7 @obama_dany yeah right mark
# Words: ['@mark_hernandez7', '@obama_dany', 'yeah', 'right', 'mark']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm still puzzled how my brother says the whole Republican Party will be gone if Bernie sanders is elected 🙄
# Words: ["I'm", 'still', 'puzzled', 'how', 'my', 'brother', 'says', 'the', 'whole', 'Republican', 'Party', 'will', 'be', 'gone', 'if', 'Bernie', 'sanders', 'is', 'elected', '🙄']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Couldn't have asked for a better way to spend spring break!😍 I love you babe!❤️
# Words: ["Couldn't", 'have', 'asked', 'for', 'a', 'better', 'way', 'to', 'spend', 'spring', 'break!😍', 'I', 'love', 'you', 'babe!❤️']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: "Go stuffed"
# Words: ['"Go', 'stuffed"']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @Matt3lopez @ me
# Words: ['@Matt3lopez', '@', 'me']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @Forsaken_Talent no shit there brothers haha
# Words: ['@Forsaken_Talent', 'no', 'shit', 'there', 'brothers', 'haha']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: You sleep baby! 😂😂😂
# Words: ['You', 'sleep', 'baby!', '😂😂😂']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: it's sad to see the good ones die young 😕
# Words: ["it's", 'sad', 'to', 'see', 'the', 'good', 'ones', 'die', 'young', '😕']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Mayhap you regret nothing...what you say...what you do... who cares, right? It's your life, live it the way you want, do what you want, say
# Words: ['Mayhap', 'you', 'regret', 'nothing...what', 'you', 'say...what', 'you', 'do...', 'who', 'cares,', 'right?', "It's", 'your', 'life,', 'live', 'it', 'the', 'way', 'you', 'want,', 'do', 'what', 'you', 'want,', 'say']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Lolllllll fuck u
# Words: ['Lolllllll', 'fuck', 'u']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Tip it back🍻
# Words: ['Tip', 'it', 'back🍻']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: OClostfound Lost prescription glasses. Purple speckeled frames..Michael Kors (Laguna/San Juan): I lost my…
# Words: ['OClostfound', 'Lost', 'prescription', 'glasses.', 'Purple', 'speckeled', 'frames..Michael', 'Kors', '(Laguna/San', 'Juan):', 'I', 'lost', 'my…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.77900465, 'longitude': -117.83961296}
# Distance: 4647.310484149643
#
#
#
#
# Text: @assleyvega she says to @ her
# Words: ['@assleyvega', 'she', 'says', 'to', '@', 'her']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: IDeclareSocialMediaWarOn
#
# Im 2 chicken shit to do this myself but digital war btwn advocates of competing portals might save the weaker 1
# Words: ['IDeclareSocialMediaWarOn', 'Im', '2', 'chicken', 'shit', 'to', 'do', 'this', 'myself', 'but', 'digital', 'war', 'btwn', 'advocates', 'of', 'competing', 'portals', 'might', 'save', 'the', 'weaker', '1']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: He's a pain in my ass sometimes but I love him
# Words: ["He's", 'a', 'pain', 'in', 'my', 'ass', 'sometimes', 'but', 'I', 'love', 'him']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: she's so beautiful when she's sleeping ugh
# Words: ["she's", 'so', 'beautiful', 'when', "she's", 'sleeping', 'ugh']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Omg that was mad crazy!!! 😂
# Words: ['Omg', 'that', 'was', 'mad', 'crazy!!!', '😂']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Lmao .50 smh  .50
# bored so quote with yours
# Words: ['Lmao', '.50', 'smh', '.50', 'bored', 'so', 'quote', 'with', 'yours']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Why do people get so pressed over Halsey? She's not good to me but she doesn't deserve to be made fun of for not being able to have kids
# Words: ['Why', 'do', 'people', 'get', 'so', 'pressed', 'over', 'Halsey?', "She's", 'not', 'good', 'to', 'me', 'but', 'she', "doesn't", 'deserve', 'to', 'be', 'made', 'fun', 'of', 'for', 'not', 'being', 'able', 'to', 'have', 'kids']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I like to pour my feelings to her if I'm not sleeping, and I'm not sleeping sooooooo
# Words: ['I', 'like', 'to', 'pour', 'my', 'feelings', 'to', 'her', 'if', "I'm", 'not', 'sleeping,', 'and', "I'm", 'not', 'sleeping', 'sooooooo']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: “@GuyCodes: Professors during finals week
# Words: ['“@GuyCodes:', 'Professors', 'during', 'finals', 'week']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Celebrating the birthday girl! wine winetasting crystalbeth givemeanicolegivemeadime…
# Words: ['Celebrating', 'the', 'birthday', 'girl!', 'wine', 'winetasting', 'crystalbeth', 'givemeanicolegivemeadime…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.16977713, 'longitude': -122.05456777}
# Distance: 531936.9426813764
#
#
#
#
# Text: I just had this FUCKIN SONG stuck in my head smh
# Words: ['I', 'just', 'had', 'this', 'FUCKIN', 'SONG', 'stuck', 'in', 'my', 'head', 'smh']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I can't 😂😂 Hi @Uber_Support one of your drivers called me a fat cunt then pushed me out of the car on the highway. This was her
# Words: ['I', "can't", '😂😂', 'Hi', '@Uber_Support', 'one', 'of', 'your', 'drivers', 'called', 'me', 'a', 'fat', 'cunt', 'then', 'pushed', 'me', 'out', 'of', 'the', 'car', 'on', 'the', 'highway.', 'This', 'was', 'her']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: what you want - who cares what the effect is on your family...on your loved ones...on your friends...  It's your life.. you're the only one
# Words: ['what', 'you', 'want', '-', 'who', 'cares', 'what', 'the', 'effect', 'is', 'on', 'your', 'family...on', 'your', 'loved', 'ones...on', 'your', 'friends...', "It's", 'your', 'life..', "you're", 'the', 'only', 'one']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Long drive to the beach bumping drake album take care 💔😭
# Words: ['Long', 'drive', 'to', 'the', 'beach', 'bumping', 'drake', 'album', 'take', 'care', '💔😭']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @_kartrinna_ AH ILY TRIN BEAN 💞😭
# Words: ['@_kartrinna_', 'AH', 'ILY', 'TRIN', 'BEAN', '💞😭']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I just tried to plug my ps4 controller into my iphone charger fucking goodbye
# Words: ['I', 'just', 'tried', 'to', 'plug', 'my', 'ps4', 'controller', 'into', 'my', 'iphone', 'charger', 'fucking', 'goodbye']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @melodiaa__ better come see me
# Words: ['@melodiaa__', 'better', 'come', 'see', 'me']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: who's important in it...right?
# Words: ["who's", 'important', 'in', 'it...right?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Pray have faith hope. SVU Prayers are magical. @ San Francisco Bay
# Words: ['Pray', 'have', 'faith', 'hope.', 'SVU', 'Prayers', 'are', 'magical.', '@', 'San', 'Francisco', 'Bay']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.70833333, 'longitude': -122.28027778}
# Distance: 588242.3575806067
#
#
#
#
# Text: This is stupid.
# Words: ['This', 'is', 'stupid.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @FirestormSixSSC make this instead, delicious!
# Words: ['@FirestormSixSSC', 'make', 'this', 'instead,', 'delicious!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: In-N-Out line always poppin' 🙄
# Words: ['In-N-Out', 'line', 'always', "poppin'", '🙄']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.69952021, 'longitude': -123.01200012}
# Distance: 634149.5160484071
#
#
#
#
# Text: How can you have no regrets?
# Words: ['How', 'can', 'you', 'have', 'no', 'regrets?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Maggie's birthday wish wins.
# Words: ["Maggie's", 'birthday', 'wish', 'wins.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm so annoyed
# Words: ["I'm", 'so', 'annoyed']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: So thankful for @JohnnyBoi_1
# Words: ['So', 'thankful', 'for', '@JohnnyBoi_1']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @lexiflores55 happy birthday lexi!!💗
# Words: ['@lexiflores55', 'happy', 'birthday', 'lexi!!💗']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @losgrowIers omg that's so close literally like 10 minutes away
# Words: ['@losgrowIers', 'omg', "that's", 'so', 'close', 'literally', 'like', '10', 'minutes', 'away']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Need a girl to be my Sunday Candy 🍭
# Words: ['Need', 'a', 'girl', 'to', 'be', 'my', 'Sunday', 'Candy', '🍭']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: finally bought new headphones since anderson lost mine in hawaii 🙄🙌🏽
# Words: ['finally', 'bought', 'new', 'headphones', 'since', 'anderson', 'lost', 'mine', 'in', 'hawaii', '🙄🙌🏽']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I miss both y'all 🙄🙄 I miss my bestfriend more 🤕 @joeigee
# Words: ['I', 'miss', 'both', "y'all", '🙄🙄', 'I', 'miss', 'my', 'bestfriend', 'more', '🤕', '@joeigee']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I swear I always put my nigga in check lmfao
# Words: ['I', 'swear', 'I', 'always', 'put', 'my', 'nigga', 'in', 'check', 'lmfao']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Is there no cutting moment where you said something and hurt someone you cared about - family, friend, lover...something you wish you
# Words: ['Is', 'there', 'no', 'cutting', 'moment', 'where', 'you', 'said', 'something', 'and', 'hurt', 'someone', 'you', 'cared', 'about', '-', 'family,', 'friend,', 'lover...something', 'you', 'wish', 'you']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: id like to walk around in your mind someday
# Words: ['id', 'like', 'to', 'walk', 'around', 'in', 'your', 'mind', 'someday']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'll just do it on Twitter so you guys get what I feel towards her
# Words: ["I'll", 'just', 'do', 'it', 'on', 'Twitter', 'so', 'you', 'guys', 'get', 'what', 'I', 'feel', 'towards', 'her']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: S/o to the homies that always send me addys to parties going on 🙌🏼😭
# Words: ['S/o', 'to', 'the', 'homies', 'that', 'always', 'send', 'me', 'addys', 'to', 'parties', 'going', 'on', '🙌🏼😭']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I strive to make you happy 😊😊
# Words: ['I', 'strive', 'to', 'make', 'you', 'happy', '😊😊']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Friends are those rare people who ask how we are and then wait to hear the answer.
#
# Ed…
# Words: ['Friends', 'are', 'those', 'rare', 'people', 'who', 'ask', 'how', 'we', 'are', 'and', 'then', 'wait', 'to', 'hear', 'the', 'answer.', 'Ed…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.709604, 'longitude': -117.988727}
# Distance: 14018.636251536382
#
#
#
#
# Text: @IsaiahRico running a damn marathon
# Words: ['@IsaiahRico', 'running', 'a', 'damn', 'marathon']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: could take back?
# Words: ['could', 'take', 'back?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Don't forget to Vote Vote JaDines
# LoveMeTHISTIME
# Words: ["Don't", 'forget', 'to', 'Vote', 'Vote', 'JaDines', 'LoveMeTHISTIME']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Gotta get rose one omg  A few of our baseball cases! 📱🔥⚾️
# Words: ['Gotta', 'get', 'rose', 'one', 'omg', 'A', 'few', 'of', 'our', 'baseball', 'cases!', '📱🔥⚾️']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @phvniebo thank you 😛😌
# Words: ['@phvniebo', 'thank', 'you', '😛😌']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Y'all want cheap merch?! Fuck then go make it yourself!
# Words: ["Y'all", 'want', 'cheap', 'merch?!', 'Fuck', 'then', 'go', 'make', 'it', 'yourself!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Mi hermanito mayor ya volvió a Mexico 😔 ahora solo quedamos dos, ya no seremos mas los 3 mosqueteros😔
# Words: ['Mi', 'hermanito', 'mayor', 'ya', 'volvió', 'a', 'Mexico', '😔', 'ahora', 'solo', 'quedamos', 'dos,', 'ya', 'no', 'seremos', 'mas', 'los', '3', 'mosqueteros😔']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: You a og homie me and you carried that bishh Sabrina. We playing soon homie
# Words: ['You', 'a', 'og', 'homie', 'me', 'and', 'you', 'carried', 'that', 'bishh', 'Sabrina.', 'We', 'playing', 'soon', 'homie']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: "We're sober right now but we wrote a song about goat cheese"
# Words: ['"We\'re', 'sober', 'right', 'now', 'but', 'we', 'wrote', 'a', 'song', 'about', 'goat', 'cheese"']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @rolandoleonardo @bldlounge longbeach adhdentertainment bullshitcarl @rolandoleonardo…
# Words: ['@rolandoleonardo', '@bldlounge', 'longbeach', 'adhdentertainment', 'bullshitcarl', '@rolandoleonardo…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.78241, 'longitude': -118.162071}
# Distance: 25917.038962738072
#
#
#
#
# Text: grupokarma karmatime exotiksound exotiksoundlab @ Jess Jones…
# Words: ['grupokarma', 'karmatime', 'exotiksound', 'exotiksoundlab', '@', 'Jess', 'Jones…']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 38.4095, 'longitude': -121.82969}
# Distance: 622656.1867433033
#
#
#
#
# Text: @brettdbzfan1 you know we have plenty lol
# Words: ['@brettdbzfan1', 'you', 'know', 'we', 'have', 'plenty', 'lol']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.8958777, 'longitude': -117.8582677}
# Distance: 10875.23106172287
#
#
#
#
# Text: I'm happy
# Words: ["I'm", 'happy']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: my cat just bangs @ my door w/ these meows like he's dying but really he just wants to cuddle smh.
# Words: ['my', 'cat', 'just', 'bangs', '@', 'my', 'door', 'w/', 'these', 'meows', 'like', "he's", 'dying', 'but', 'really', 'he', 'just', 'wants', 'to', 'cuddle', 'smh.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Sometimes things happen in life that don't make any sense, but I have to just trust that these things happen for a reason.
# Words: ['Sometimes', 'things', 'happen', 'in', 'life', 'that', "don't", 'make', 'any', 'sense,', 'but', 'I', 'have', 'to', 'just', 'trust', 'that', 'these', 'things', 'happen', 'for', 'a', 'reason.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: My latest report.Track by SigFig Friday only best day out of the week😏💵💲💵 daytrading WallStreet TradeHardLiveBig
# Words: ['My', 'latest', 'report.Track', 'by', 'SigFig', 'Friday', 'only', 'best', 'day', 'out', 'of', 'the', 'week😏💵💲💵', 'daytrading', 'WallStreet', 'TradeHardLiveBig']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @AshleyKuewa @ them please
# Words: ['@AshleyKuewa', '@', 'them', 'please']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I've come to the conclusion that I am a straight joke to the entire male population
# Words: ["I've", 'come', 'to', 'the', 'conclusion', 'that', 'I', 'am', 'a', 'straight', 'joke', 'to', 'the', 'entire', 'male', 'population']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: At least we made it on the Dreamville snapchat today lol. Pretty cool. 😊
# Words: ['At', 'least', 'we', 'made', 'it', 'on', 'the', 'Dreamville', 'snapchat', 'today', 'lol.', 'Pretty', 'cool.', '😊']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Angels swept the Dodgers lol
# Words: ['Angels', 'swept', 'the', 'Dodgers', 'lol']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Nah came close, never again gon try this out
# Words: ['Nah', 'came', 'close,', 'never', 'again', 'gon', 'try', 'this', 'out']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Happy Birthday 💕 I love you girl, I hope your day is gr8!!!! Xoxo @CasillasMarla
# Words: ['Happy', 'Birthday', '💕', 'I', 'love', 'you', 'girl,', 'I', 'hope', 'your', 'day', 'is', 'gr8!!!!', 'Xoxo', '@CasillasMarla']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Have you never seen the pain well in someone's eyes from what you've done to them and realized that... you shouldn't have done that?
# Words: ['Have', 'you', 'never', 'seen', 'the', 'pain', 'well', 'in', "someone's", 'eyes', 'from', 'what', "you've", 'done', 'to', 'them', 'and', 'realized', 'that...', 'you', "shouldn't", 'have', 'done', 'that?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I have a head ache and I'm in need of some sleep
# Words: ['I', 'have', 'a', 'head', 'ache', 'and', "I'm", 'in', 'need', 'of', 'some', 'sleep']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: now i can listen to my simp music w/o anyone saying shit to me HAHAHAHAH
# Words: ['now', 'i', 'can', 'listen', 'to', 'my', 'simp', 'music', 'w/o', 'anyone', 'saying', 'shit', 'to', 'me', 'HAHAHAHAH']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @FWCAbuja it's really good! Clear and good volume
# Words: ['@FWCAbuja', "it's", 'really', 'good!', 'Clear', 'and', 'good', 'volume']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: It should be a rule that you can't post multiple times a day on Instagram!
# Words: ['It', 'should', 'be', 'a', 'rule', 'that', 'you', "can't", 'post', 'multiple', 'times', 'a', 'day', 'on', 'Instagram!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm the only person with republican views in my family hahah kms
# Words: ["I'm", 'the', 'only', 'person', 'with', 'republican', 'views', 'in', 'my', 'family', 'hahah', 'kms']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @katsuckss you name it I'll take us ;)
# Words: ['@katsuckss', 'you', 'name', 'it', "I'll", 'take', 'us', ';)']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @GeoRomero_ @TheSexuallGifs late night bro
# Words: ['@GeoRomero_', '@TheSexuallGifs', 'late', 'night', 'bro']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: to everyone out partying tonight, go ahead and have fun but please don't drink &amp; drive
# Words: ['to', 'everyone', 'out', 'partying', 'tonight,', 'go', 'ahead', 'and', 'have', 'fun', 'but', 'please', "don't", 'drink', '&amp;', 'drive']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Tell me honestly, would you still love the same?
# Words: ['Tell', 'me', 'honestly,', 'would', 'you', 'still', 'love', 'the', 'same?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Banda Guy putting me on Blast 😻🙈 BandaMensajera
# Words: ['Banda', 'Guy', 'putting', 'me', 'on', 'Blast', '😻🙈', 'BandaMensajera']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm getting real tired of this shit this is literally the last straw
# Words: ["I'm", 'getting', 'real', 'tired', 'of', 'this', 'shit', 'this', 'is', 'literally', 'the', 'last', 'straw']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: These stans that get so pressed over her existence need to be stopped. Someone needs to destroy stan twitter
# Words: ['These', 'stans', 'that', 'get', 'so', 'pressed', 'over', 'her', 'existence', 'need', 'to', 'be', 'stopped.', 'Someone', 'needs', 'to', 'destroy', 'stan', 'twitter']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Remember the animated elephants ad? About the Ivory trade. Shit was too sad
# Words: ['Remember', 'the', 'animated', 'elephants', 'ad?', 'About', 'the', 'Ivory', 'trade.', 'Shit', 'was', 'too', 'sad']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Really wish I was able to sleep rn
# Words: ['Really', 'wish', 'I', 'was', 'able', 'to', 'sleep', 'rn']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Best not go that way shiftingsands oldpa @ Salvation Mountain
# Words: ['Best', 'not', 'go', 'that', 'way', 'shiftingsands', 'oldpa', '@', 'Salvation', 'Mountain']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.25416667, 'longitude': -115.4725}
# Distance: 231955.36985099554
#
#
#
#
# Text: Que vida tan culera lmao
# Words: ['Que', 'vida', 'tan', 'culera', 'lmao']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Seeing the Sights of San Francisco @ Golden Gate Bridge
# Words: ['Seeing', 'the', 'Sights', 'of', 'San', 'Francisco', '@', 'Golden', 'Gate', 'Bridge']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.81972222, 'longitude': -122.47861111}
# Distance: 609281.019710191
#
#
#
#
# Text: Pretty much
# Words: ['Pretty', 'much']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: That you're a better person than that? That you've the /potential/ to be a better person than that? or ...do you just not care
# Words: ['That', "you're", 'a', 'better', 'person', 'than', 'that?', 'That', "you've", 'the', '/potential/', 'to', 'be', 'a', 'better', 'person', 'than', 'that?', 'or', '...do', 'you', 'just', 'not', 'care']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @JonnyBones lol he isn't even willing to limp.
# Words: ['@JonnyBones', 'lol', 'he', "isn't", 'even', 'willing', 'to', 'limp.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @jennaquino04 just @ me
# Words: ['@jennaquino04', 'just', '@', 'me']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.69955628, 'longitude': -123.01249558}
# Distance: 634184.903588199
#
#
#
#
# Text: The night has just begun 😜
# Words: ['The', 'night', 'has', 'just', 'begun', '😜']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: How can you claim to love someone ...and not care?
# Words: ['How', 'can', 'you', 'claim', 'to', 'love', 'someone', '...and', 'not', 'care?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: this has been the most productive spring break i've had in awhile!!😻🎉
# Words: ['this', 'has', 'been', 'the', 'most', 'productive', 'spring', 'break', "i've", 'had', 'in', 'awhile!!😻🎉']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: my mans went 3-7 first map and 2-8 next map gn
# Words: ['my', 'mans', 'went', '3-7', 'first', 'map', 'and', '2-8', 'next', 'map', 'gn']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: watching He Never Died on Netflix &amp; I now have a new celebrity crush in Jordan Todosey.
# Words: ['watching', 'He', 'Never', 'Died', 'on', 'Netflix', '&amp;', 'I', 'now', 'have', 'a', 'new', 'celebrity', 'crush', 'in', 'Jordan', 'Todosey.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @AshleyKuewa Plis
# Words: ['@AshleyKuewa', 'Plis']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @iheartsteph_  tfti
# Words: ['@iheartsteph_', 'tfti']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Still wanna meet Nev and Max
# Words: ['Still', 'wanna', 'meet', 'Nev', 'and', 'Max']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @zaida_luciaa @adidasladlou lmao shush
# Words: ['@zaida_luciaa', '@adidasladlou', 'lmao', 'shush']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Why does my cat hate me go to sleep demon
# Words: ['Why', 'does', 'my', 'cat', 'hate', 'me', 'go', 'to', 'sleep', 'demon']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: .@markhoppus do u like organisms
# Words: ['.@markhoppus', 'do', 'u', 'like', 'organisms']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: It's about tomorrow though...
# Words: ["It's", 'about', 'tomorrow', 'though...']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: TWT v FB
#
# IG v SC
#
# Tinder (TD?) vs Vine
# Words: ['TWT', 'v', 'FB', 'IG', 'v', 'SC', 'Tinder', '(TD?)', 'vs', 'Vine']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: you a lil horn dog
# Words: ['you', 'a', 'lil', 'horn', 'dog']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Pursuit ocsd in pursuit of a Toyota pickup want is felony evatting red1 @SoCalSafety1st @ducksfan95
# Words: ['Pursuit', 'ocsd', 'in', 'pursuit', 'of', 'a', 'Toyota', 'pickup', 'want', 'is', 'felony', 'evatting', 'red1', '@SoCalSafety1st', '@ducksfan95']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: USGS reports a M0.95 earthquake 3km ESE of Mammoth Lakes, California on 4/3/16 @ 7:43:18 UTC
# Words: ['USGS', 'reports', 'a', 'M0.95', 'earthquake', '3km', 'ESE', 'of', 'Mammoth', 'Lakes,', 'California', 'on', '4/3/16', '@', '7:43:18', 'UTC']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.6378326, 'longitude': -118.9328308}
# Distance: 436275.5374768531
#
#
#
#
# Text: USGS reports a M0.95 earthquake 3km ESE of Mammoth Lakes, California on 4/3/16 @ 7:43:18 UTC
# Words: ['USGS', 'reports', 'a', 'M0.95', 'earthquake', '3km', 'ESE', 'of', 'Mammoth', 'Lakes,', 'California', 'on', '4/3/16', '@', '7:43:18', 'UTC']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.6378326, 'longitude': -118.9328308}
# Distance: 436275.5374768531
#
#
#
#
# Text: Do you go hard like Vladimir Putin? @themiaaaaa
# Words: ['Do', 'you', 'go', 'hard', 'like', 'Vladimir', 'Putin?', '@themiaaaaa']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Dodgers vs Angels
# Words: ['Dodgers', 'vs', 'Angels']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I feel so useless 🙁
# Words: ['I', 'feel', 'so', 'useless', '🙁']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Tell me why my mother decides to throw my stuff out of my closet.
# Words: ['Tell', 'me', 'why', 'my', 'mother', 'decides', 'to', 'throw', 'my', 'stuff', 'out', 'of', 'my', 'closet.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: My cat just threw up on my floor...how's your night going?😀
# Words: ['My', 'cat', 'just', 'threw', 'up', 'on', 'my', "floor...how's", 'your', 'night', 'going?😀']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Anyone up for a late night convo?
# Words: ['Anyone', 'up', 'for', 'a', 'late', 'night', 'convo?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Finally, pavement oldpa @ Salvation Mountain
# Words: ['Finally,', 'pavement', 'oldpa', '@', 'Salvation', 'Mountain']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.25416667, 'longitude': -115.4725}
# Distance: 231955.36985099554
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 37.69952243, 'longitude': -123.01189796}
# Distance: 634142.9295366437
#
#
#
#
# Text: I LOVE how tall you are!! 😍 @IGGYAZALEA
# Words: ['I', 'LOVE', 'how', 'tall', 'you', 'are!!', '😍', '@IGGYAZALEA']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: That moment when you realize that anything you say right now...when you're in the midst of anger..will do nothing more than make you regret
# Words: ['That', 'moment', 'when', 'you', 'realize', 'that', 'anything', 'you', 'say', 'right', 'now...when', "you're", 'in', 'the', 'midst', 'of', 'anger..will', 'do', 'nothing', 'more', 'than', 'make', 'you', 'regret']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @PennyHicks13 @RFriar @az_valentine @jhewitt1280 @DianeHauschildt @EsotericCD nope, don't follow anyone who bashes Trump
# Words: ['@PennyHicks13', '@RFriar', '@az_valentine', '@jhewitt1280', '@DianeHauschildt', '@EsotericCD', 'nope,', "don't", 'follow', 'anyone', 'who', 'bashes', 'Trump']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Goooooooodnight!
# Words: ['Goooooooodnight!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: 🏆🏆🏆🐔🐔🐔🚫🚫🚫 Maggie's birthday wish wins.
# Words: ['🏆🏆🏆🐔🐔🐔🚫🚫🚫', "Maggie's", 'birthday', 'wish', 'wins.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: it tomorrow...when you're not.
# Words: ['it', 'tomorrow...when', "you're", 'not.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: This week was by far one of the most lit weeks. spring break 2 next week
# Words: ['This', 'week', 'was', 'by', 'far', 'one', 'of', 'the', 'most', 'lit', 'weeks.', 'spring', 'break', '2', 'next', 'week']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @lilibeanss @allywhyy
# Words: ['@lilibeanss', '@allywhyy']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: RYAN PIERSON😌👌🏻 I guess this one too 💤
# Words: ['RYAN', 'PIERSON😌👌🏻', 'I', 'guess', 'this', 'one', 'too', '💤']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I recommend the app WordAcademy! Find the hidden words!
# Words: ['I', 'recommend', 'the', 'app', 'WordAcademy!', 'Find', 'the', 'hidden', 'words!']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.843794, 'longitude': -117.942546}
# Distance: 7343.9914639724275
#
#
#
#
# Text: @lindsaylizzle @anhpdoan I want a shirt
# Words: ['@lindsaylizzle', '@anhpdoan', 'I', 'want', 'a', 'shirt']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: What a 15teen, 💯
# Words: ['What', 'a', '15teen,', '💯']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: My back is seriously killing me though😥 today was seriously the busiest it's ever been😒
# Words: ['My', 'back', 'is', 'seriously', 'killing', 'me', 'though😥', 'today', 'was', 'seriously', 'the', 'busiest', "it's", 'ever', 'been😒']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Adulting at the Beach with these babes @ Huntington Beach, California
# Words: ['Adulting', 'at', 'the', 'Beach', 'with', 'these', 'babes', '@', 'Huntington', 'Beach,', 'California']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.6929, 'longitude': -118.0}
# Distance: 16083.93751528105
#
#
#
#
# Text: @nathangonn thanks Nathan! 🤘🏼😋
# Words: ['@nathangonn', 'thanks', 'Nathan!', '🤘🏼😋']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Controlla // Drake👌🏽👌🏽👌🏽
# Words: ['Controlla', '//', 'Drake👌🏽👌🏽👌🏽']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Pursuit passing 5 80mph
# Words: ['Pursuit', 'passing', '5', '80mph']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: The ones in our chat minus Taylor  🌾🌾🌾🌾
# Words: ['The', 'ones', 'in', 'our', 'chat', 'minus', 'Taylor', '🌾🌾🌾🌾']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm crying I'm so dumb HAHHAHA
# Words: ["I'm", 'crying', "I'm", 'so', 'dumb', 'HAHHAHA']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: lol no I'm the biggest belieber there is
# Words: ['lol', 'no', "I'm", 'the', 'biggest', 'belieber', 'there', 'is']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Das my queen. Das my queen
# Words: ['Das', 'my', 'queen.', 'Das', 'my', 'queen']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I came home to my closet empty.
# Words: ['I', 'came', 'home', 'to', 'my', 'closet', 'empty.']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: She would be the one beating them up 84. ya bestfriend getting beat up… you jumping in?
# Words: ['She', 'would', 'be', 'the', 'one', 'beating', 'them', 'up', '84.', 'ya', 'bestfriend', 'getting', 'beat', 'up…', 'you', 'jumping', 'in?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: wow guys it's already 12:46 am and y'all are still fuckin loud like we're tryna sleep here!!!!!
# Words: ['wow', 'guys', "it's", 'already', '12:46', 'am', 'and', "y'all", 'are', 'still', 'fuckin', 'loud', 'like', "we're", 'tryna', 'sleep', 'here!!!!!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: 😷🚮
# Words: ['😷🚮']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Floaty float
# Words: ['Floaty', 'float']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @arevk7 tru I don't think I'll be able to perfect it like u have. plus I'm too busy playing ping pong in the middle of the street anyways
# Words: ['@arevk7', 'tru', 'I', "don't", 'think', "I'll", 'be', 'able', 'to', 'perfect', 'it', 'like', 'u', 'have.', 'plus', "I'm", 'too', 'busy', 'playing', 'ping', 'pong', 'in', 'the', 'middle', 'of', 'the', 'street', 'anyways']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: you're my everything
# Words: ["you're", 'my', 'everything']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Don't save her!
# Words: ["Don't", 'save', 'her!']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: fml
# Words: ['fml']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @HaileyyRafter @WeLoveRobDyrdek so true lol
# Words: ['@HaileyyRafter', '@WeLoveRobDyrdek', 'so', 'true', 'lol']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Stop the violence!! @morrissey_son @Melosmilees_ I love oth and Melo will probably like it too
# Words: ['Stop', 'the', 'violence!!', '@morrissey_son', '@Melosmilees_', 'I', 'love', 'oth', 'and', 'Melo', 'will', 'probably', 'like', 'it', 'too']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I'm having really bad jaw issues and I have to go to the doctors 😪
# Words: ["I'm", 'having', 'really', 'bad', 'jaw', 'issues', 'and', 'I', 'have', 'to', 'go', 'to', 'the', 'doctors', '😪']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Happy birthday @briannna_13 🎉
# Words: ['Happy', 'birthday', '@briannna_13', '🎉']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Maybe in a Jeep next time oldpa @ Salvation Mountain
# Words: ['Maybe', 'in', 'a', 'Jeep', 'next', 'time', 'oldpa', '@', 'Salvation', 'Mountain']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.25416667, 'longitude': -115.4725}
# Distance: 231955.36985099554
#
#
#
#
# Text: I love you through everything
# Words: ['I', 'love', 'you', 'through', 'everything']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @Ernestiina8 Austin and Anthony
# Words: ['@Ernestiina8', 'Austin', 'and', 'Anthony']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @beatricewhitee it was a dream ok
# Words: ['@beatricewhitee', 'it', 'was', 'a', 'dream', 'ok']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: I hate to see people feel absolutely helpless
# Words: ['I', 'hate', 'to', 'see', 'people', 'feel', 'absolutely', 'helpless']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: You know Mexico is lit when a man try's selling you Cuban cigars (I'm 15)
# Words: ['You', 'know', 'Mexico', 'is', 'lit', 'when', 'a', 'man', "try's", 'selling', 'you', 'Cuban', 'cigars', "(I'm", '15)']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Me @ everyone What if you're wrong?
# Words: ['Me', '@', 'everyone', 'What', 'if', "you're", 'wrong?']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: @BartBordelon come to manila philippines ok? :)))))))))
# Words: ['@BartBordelon', 'come', 'to', 'manila', 'philippines', 'ok?', ':)))))))))']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Wish the state of Virginia didn't exist
# Words: ['Wish', 'the', 'state', 'of', 'Virginia', "didn't", 'exist']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Mar jr. You a homie brotha we gotta grind one full day when I'm not salty lmao
# Words: ['Mar', 'jr.', 'You', 'a', 'homie', 'brotha', 'we', 'gotta', 'grind', 'one', 'full', 'day', 'when', "I'm", 'not', 'salty', 'lmao']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Lmao u wish
# Words: ['Lmao', 'u', 'wish']
# Date: 2016-04-03
# Hour: 7
#
#
#
#
# Text: Hospitality Job in SantaAna, CA: Barista at HMSHost
# Words: ['Hospitality', 'Job', 'in', 'SantaAna,', 'CA:', 'Barista', 'at', 'HMSHost']
# Date: 2016-04-03
# Hour: 7
# Coordinates: {'latitude': 33.7455731, 'longitude': -117.8678338}
# Distance: 6201.949087886304
#
#
#
#
# Text: Happy birthday princess ✨👑
# I hope you have a wonderful day &amp; I love you so much 💞
# @___paoladuran
# ...
# Words: ['Hmu', 'I', 'give', 'good', 'advise', '(occasionally)', 'I', 'sometimes', 'love', 'Jen', 'pt.', '2']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: FT @brisbaneroar 2-1 @NewcastleJetsFC BRIvNEW ALeague BeautifulGame @FTSAUS @thestoppagetime
# Words: ['FT', '@brisbaneroar', '2-1', '@NewcastleJetsFC', 'BRIvNEW', 'ALeague', 'BeautifulGame', '@FTSAUS', '@thestoppagetime']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Not_jojo
# Words: ['@Not_jojo']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @handydandyriley LET ME TAK BRUNO TO THE DOG BEACH
# Words: ['@handydandyriley', 'LET', 'ME', 'TAK', 'BRUNO', 'TO', 'THE', 'DOG', 'BEACH']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: YAS! Our new loyalty program SprinklesPerks is here! Sign up at
# Words: ['YAS!', 'Our', 'new', 'loyalty', 'program', 'SprinklesPerks', 'is', 'here!', 'Sign', 'up', 'at']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Talks with @lovelyjeneve are always good 👯😅❣
# Words: ['Talks', 'with', '@lovelyjeneve', 'are', 'always', 'good', '👯😅❣']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Why am I not tired ?
# Words: ['Why', 'am', 'I', 'not', 'tired', '?']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: DAB 😂 HAHAHAHAHAHAHAHA
# Words: ['DAB', '😂', 'HAHAHAHAHAHAHAHA']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @kittenring did you know that Cesar Milan abuses animals
# Words: ['@kittenring', 'did', 'you', 'know', 'that', 'Cesar', 'Milan', 'abuses', 'animals']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Oh hey
# Words: ['Oh', 'hey']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: The new night screen thing on iPhones is one of the better things to happen to me in 2016
# Words: ['The', 'new', 'night', 'screen', 'thing', 'on', 'iPhones', 'is', 'one', 'of', 'the', 'better', 'things', 'to', 'happen', 'to', 'me', 'in', '2016']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Xoxo_Haleee you were sleeping just fine in the back of the truck?🤔
# Words: ['@Xoxo_Haleee', 'you', 'were', 'sleeping', 'just', 'fine', 'in', 'the', 'back', 'of', 'the', 'truck?🤔']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: noelle is so annoying i hate her
# Words: ['noelle', 'is', 'so', 'annoying', 'i', 'hate', 'her']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @lilfreshbang831 Ha SIKE
# Words: ['@lilfreshbang831', 'Ha', 'SIKE']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @alyssabuzzello @ThiefSupreme We wanted to crowdsurf to it...
# Words: ['@alyssabuzzello', '@ThiefSupreme', 'We', 'wanted', 'to', 'crowdsurf', 'to', 'it...']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Holla at a real nigga
# Words: ['Holla', 'at', 'a', 'real', 'nigga']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Where's my girl at
# Words: ["Where's", 'my', 'girl', 'at']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: FuckRon
# Words: ['FuckRon']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @OSUJace ok well that's good then. But some of the other big names I would hope didn't get paid to lend their face to the cause
# Words: ['@OSUJace', 'ok', 'well', "that's", 'good', 'then.', 'But', 'some', 'of', 'the', 'other', 'big', 'names', 'I', 'would', 'hope', "didn't", 'get', 'paid', 'to', 'lend', 'their', 'face', 'to', 'the', 'cause']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Yes! Customer Buying Decisions are Influenced by Social Media (research)
#
# Words: ['Yes!', 'Customer', 'Buying', 'Decisions', 'are', 'Influenced', 'by', 'Social', 'Media', '(research)']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: this is my supa hot fiya gf
# Words: ['this', 'is', 'my', 'supa', 'hot', 'fiya', 'gf']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Omg i just saw someone from my childhood 😂😁😎
# Words: ['Omg', 'i', 'just', 'saw', 'someone', 'from', 'my', 'childhood', '😂😁😎']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: when will i meet @camilacabello97 and tell her how much i love her and how much she means to me
# Words: ['when', 'will', 'i', 'meet', '@camilacabello97', 'and', 'tell', 'her', 'how', 'much', 'i', 'love', 'her', 'and', 'how', 'much', 'she', 'means', 'to', 'me']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: that was so gross omg
# Words: ['that', 'was', 'so', 'gross', 'omg']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: SCHEDULED @PerthGloryFC 0-0 @MelbourneCity PERvMCY ALeague BeautifulGame @thestoppagetime @FTSAUS
# Words: ['SCHEDULED', '@PerthGloryFC', '0-0', '@MelbourneCity', 'PERvMCY', 'ALeague', 'BeautifulGame', '@thestoppagetime', '@FTSAUS']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: My uber literally looks &amp; acts like Dwight Schrute I am dying
# Words: ['My', 'uber', 'literally', 'looks', '&amp;', 'acts', 'like', 'Dwight', 'Schrute', 'I', 'am', 'dying']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Not down to sleep yet
# Words: ['Not', 'down', 'to', 'sleep', 'yet']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Just wanna make her happy 25/8
# Words: ['Just', 'wanna', 'make', 'her', 'happy', '25/8']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: spring break was lit
# Words: ['spring', 'break', 'was', 'lit']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: I look so good without you
# Words: ['I', 'look', 'so', 'good', 'without', 'you']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Juhnelly and Francisco are so adorable I can't 😭✨
# Words: ['Juhnelly', 'and', 'Francisco', 'are', 'so', 'adorable', 'I', "can't", '😭✨']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: I have to get up for a tournament in 4 hours why am I up 🙂
# Words: ['I', 'have', 'to', 'get', 'up', 'for', 'a', 'tournament', 'in', '4', 'hours', 'why', 'am', 'I', 'up', '🙂']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: It's always a bad idea staying up this late when I'm literally walking around a whole land the next day
# Words: ["It's", 'always', 'a', 'bad', 'idea', 'staying', 'up', 'this', 'late', 'when', "I'm", 'literally', 'walking', 'around', 'a', 'whole', 'land', 'the', 'next', 'day']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text:
# Words: []
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @wittlest_wittle you're actually married to me so that's your relationship status bye
# Words: ['@wittlest_wittle', "you're", 'actually', 'married', 'to', 'me', 'so', "that's", 'your', 'relationship', 'status', 'bye']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Well then
# Words: ['Well', 'then']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Almirables_4thI @BennyJRosario @4thImpactMusic @4thimpact_mira @4iville any offers for Ben yet?
# Words: ['@Almirables_4thI', '@BennyJRosario', '@4thImpactMusic', '@4thimpact_mira', '@4iville', 'any', 'offers', 'for', 'Ben', 'yet?']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: who s not going to sleep anytime soon and wants to talk
# Words: ['who', 's', 'not', 'going', 'to', 'sleep', 'anytime', 'soon', 'and', 'wants', 'to', 'talk']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: both of yall move back
# Words: ['both', 'of', 'yall', 'move', 'back']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: 🤔 Best mood in a good while and people still manage to kill it, I give up
# Words: ['🤔', 'Best', 'mood', 'in', 'a', 'good', 'while', 'and', 'people', 'still', 'manage', 'to', 'kill', 'it,', 'I', 'give', 'up']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @kingVec7 I breath nascar nexxx can suck it and I use fresh's line ups for everything besides nascar
# Words: ['@kingVec7', 'I', 'breath', 'nascar', 'nexxx', 'can', 'suck', 'it', 'and', 'I', 'use', "fresh's", 'line', 'ups', 'for', 'everything', 'besides', 'nascar']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Fear two things, bein broke and dying
# Words: ['Fear', 'two', 'things,', 'bein', 'broke', 'and', 'dying']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @cruz_maraya thanks arLEAN 😎
# Words: ['@cruz_maraya', 'thanks', 'arLEAN', '😎']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Xoxo_Haleee that's rough, maybe you should take a couple solid pulls of NyQuil ¯\_(ツ)_/¯
# Words: ['@Xoxo_Haleee', "that's", 'rough,', 'maybe', 'you', 'should', 'take', 'a', 'couple', 'solid', 'pulls', 'of', 'NyQuil', '¯\\_(ツ)_/¯']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Herika qnes
# Words: ['Herika', 'qnes']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: I swear @tovarbrianna_ bout to kill some one 👀😂 dontmesswithherman
# Words: ['I', 'swear', '@tovarbrianna_', 'bout', 'to', 'kill', 'some', 'one', '👀😂', 'dontmesswithherman']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Drunken quesadilla flip. 😂😂😂😂😂
# Words: ['Drunken', 'quesadilla', 'flip.', '😂😂😂😂😂']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: High*  You don't know how drunk you really are until you look at yourself in the bathroom mirror
# Words: ['High*', 'You', "don't", 'know', 'how', 'drunk', 'you', 'really', 'are', 'until', 'you', 'look', 'at', 'yourself', 'in', 'the', 'bathroom', 'mirror']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @brianmrob @calliestrouse10 nah she said khonny
# Words: ['@brianmrob', '@calliestrouse10', 'nah', 'she', 'said', 'khonny']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @fosHizlmynizzle GOVBALL2016
# Words: ['@fosHizlmynizzle', 'GOVBALL2016']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Are you ready for some seez dah bedar fun
# Words: ['Are', 'you', 'ready', 'for', 'some', 'seez', 'dah', 'bedar', 'fun']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @rainl0rd @calvin_okay that's a bathtub
# Words: ['@rainl0rd', '@calvin_okay', "that's", 'a', 'bathtub']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Had fun with the homies. They got it boomin'
# Words: ['Had', 'fun', 'with', 'the', 'homies.', 'They', 'got', 'it', "boomin'"]
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: This is not the way I thought my life was supposed to be
# Words: ['This', 'is', 'not', 'the', 'way', 'I', 'thought', 'my', 'life', 'was', 'supposed', 'to', 'be']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Staying up watching movies again 😋
# Words: ['Staying', 'up', 'watching', 'movies', 'again', '😋']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @OSUJace  or even if they'd donate whatever their booking fee is to the cause would be nice too
# Words: ['@OSUJace', 'or', 'even', 'if', "they'd", 'donate', 'whatever', 'their', 'booking', 'fee', 'is', 'to', 'the', 'cause', 'would', 'be', 'nice', 'too']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @lovelymayrah you good?
# Words: ['@lovelymayrah', 'you', 'good?']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Foreal fuck cats fuckrr
# Words: ['Foreal', 'fuck', 'cats', 'fuckrr']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Nicki_Mariee 🙌
# Words: ['@Nicki_Mariee', '🙌']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @lilfreshbang831 there you go. An attitude for no reason 😒
# Words: ['@lilfreshbang831', 'there', 'you', 'go.', 'An', 'attitude', 'for', 'no', 'reason', '😒']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: hoe shut the fuck up
# Words: ['hoe', 'shut', 'the', 'fuck', 'up']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: lmfao
# Words: ['lmfao']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: watch my new musicvideo on youtube
# Words: ['watch', 'my', 'new', 'musicvideo', 'on', 'youtube']
# Date: 2016-04-03
# Hour: 8
# Coordinates: {'latitude': 33.6929, 'longitude': -118.0}
# Distance: 16083.93751528105
#
#
#
#
# Text: @flo2changz the right side of your avi😍😍😍
# Words: ['@flo2changz', 'the', 'right', 'side', 'of', 'your', 'avi😍😍😍']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @fosHizlmynizzle you know just what we want
# Words: ['@fosHizlmynizzle', 'you', 'know', 'just', 'what', 'we', 'want']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Hold the person you love close to you
# Words: ['Hold', 'the', 'person', 'you', 'love', 'close', 'to', 'you']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: When you're trying to explain to someone this is your dad.... And they don't believe you. 😂😂😂 iswearimadopted
# Words: ['When', "you're", 'trying', 'to', 'explain', 'to', 'someone', 'this', 'is', 'your', 'dad....', 'And', 'they', "don't", 'believe', 'you.', '😂😂😂', 'iswearimadopted']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Literally so dumb how ppl lie abt drugs, alcohol, sex etc etc... It doesn't make u look cool esp when everyone knows ur a lyin ass
# Words: ['Literally', 'so', 'dumb', 'how', 'ppl', 'lie', 'abt', 'drugs,', 'alcohol,', 'sex', 'etc', 'etc...', 'It', "doesn't", 'make', 'u', 'look', 'cool', 'esp', 'when', 'everyone', 'knows', 'ur', 'a', 'lyin', 'ass']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @kittehbs i jsut wanna c it on AO3 so i can sub &amp; kudos it u hv no idea how blueballed i felt on the gdoc cos i couldnt comment/kudos/sub it
# Words: ['@kittehbs', 'i', 'jsut', 'wanna', 'c', 'it', 'on', 'AO3', 'so', 'i', 'can', 'sub', '&amp;', 'kudos', 'it', 'u', 'hv', 'no', 'idea', 'how', 'blueballed', 'i', 'felt', 'on', 'the', 'gdoc', 'cos', 'i', 'couldnt', 'comment/kudos/sub', 'it']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Andr3w17_ easy for you. Mexico right down the street. Cambodia far from here
# Words: ['@Andr3w17_', 'easy', 'for', 'you.', 'Mexico', 'right', 'down', 'the', 'street.', 'Cambodia', 'far', 'from', 'here']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: AMISHA WAS LIKE GIVING ME SHIT FOR GOING TO SD &amp; NOT VISITING HER WHEN SHE WAS LITERALLY IN COSTA MESA WTF
# Words: ['AMISHA', 'WAS', 'LIKE', 'GIVING', 'ME', 'SHIT', 'FOR', 'GOING', 'TO', 'SD', '&amp;', 'NOT', 'VISITING', 'HER', 'WHEN', 'SHE', 'WAS', 'LITERALLY', 'IN', 'COSTA', 'MESA', 'WTF']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @swagmeoutarty boofer
# Words: ['@swagmeoutarty', 'boofer']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @oDrafty @Arnold7146 I wasn't there for the pancakes 😕
# Words: ['@oDrafty', '@Arnold7146', 'I', "wasn't", 'there', 'for', 'the', 'pancakes', '😕']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @Not_jojo
# Words: ['@Not_jojo']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: Saw my first potato bug today and wanted to learn more.
# Words: ['Saw', 'my', 'first', 'potato', 'bug', 'today', 'and', 'wanted', 'to', 'learn', 'more.']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @DawnnKatie hi lets chat
# Words: ['@DawnnKatie', 'hi', 'lets', 'chat']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: @DILLONFRANCIS YOU WERE FUCKING AMAZING TONIGHT I LOVE YOU ❤️🙌🏼
# Words: ['@DILLONFRANCIS', 'YOU', 'WERE', 'FUCKING', 'AMAZING', 'TONIGHT', 'I', 'LOVE', 'YOU', '❤️🙌🏼']
# Date: 2016-04-03
# Hour: 8
#
#
#
#
# Text: So. Hungry.
# Words: ['So.', 'Hungry.']
# Date: 2016-04-03
# Hour: 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [20], line 332
#     329 # !! COGNITION !!
#     331 tokens = nltk.word_tokenize(text)  # Create a list of tokens
# --> 332 tokens_tagged = nltk.pos_tag(tokens, tagset='universal')
#     334 pos_tokens = ''
#     336 # Loop the dict of tokens
#
# File ~/.local/lib/python3.9/site-packages/nltk/tag/__init__.py:166, in pos_tag(tokens, tagset, lang)
#     141 """
#     142 Use NLTK's currently recommended part of speech tagger to
#     143 tag the given list of tokens.
#    (...)
#     163 :rtype: list(tuple(str, str))
#     164 """
#     165 tagger = _get_tagger(lang)
# --> 166 return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~/.local/lib/python3.9/site-packages/nltk/tag/__init__.py:123, in _pos_tag(tokens, tagset, tagger, lang)
#     120     raise TypeError("tokens: expected a list of strings, got a string")
#     122 else:
# --> 123     tagged_tokens = tagger.tag(tokens)
#     124     if tagset:  # Maps to the specified tagset.
#     125         if lang == "eng":
#
# File ~/.local/lib/python3.9/site-packages/nltk/tag/perceptron.py:187, in PerceptronTagger.tag(self, tokens, return_conf, use_tagdict)
#     185 if not tag:
#     186     features = self._get_features(i, word, context, prev, prev2)
# --> 187     tag, conf = self.model.predict(features, return_conf)
#     188 output.append((word, tag, conf) if return_conf == True else (word, tag))
#     190 prev2 = prev
#
# File ~/.local/lib/python3.9/site-packages/nltk/tag/perceptron.py:69, in AveragedPerceptron.predict(self, features, return_conf)
#      66         scores[label] += value * weight
#      68 # Do a secondary alphabetic sort, for stability
# ---> 69 best_label = max(self.classes, key=lambda label: (scores[label], label))
#      70 # compute the confidence
#      71 conf = max(self._softmax(scores)) if return_conf == True else None
#
# File ~/.local/lib/python3.9/site-packages/nltk/tag/perceptron.py:69, in AveragedPerceptron.predict.<locals>.<lambda>(label)
#      66         scores[label] += value * weight
#      68 # Do a secondary alphabetic sort, for stability
# ---> 69 best_label = max(self.classes, key=lambda label: (scores[label], label))
#      70 # compute the confidence
#      71 conf = max(self._softmax(scores)) if return_conf == True else None
#
# KeyboardInterrupt:
